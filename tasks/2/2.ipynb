# %%
import turtle

# %%
m = 100
a = 5.7
b = 9.6
turtle.speed(0)
turtle.penup()

# %%
def sign(x):
    return (x > 0) - (x < 0)

# %%
def fdivmod(x, y):
    return sign(x)*(abs(x)//y), sign(x)*(abs(x) % y)

# %%
for x in range(-100, 100):
    for y in range(-100, 100):
        x /= 10

        y /= 10


"".replace
# Out:
# -4.0000000000000034e-101 0.0
# -4.000000000000004e-102 0.1
# -4.000000000000004e-103 0.2
# -4.000000000000004e-104 0.3
# -4.000000000000004e-105 0.4
# -4.0000000000000036e-106 0.5
# -4.0000000000000036e-107 0.6
# -4.000000000000004e-108 0.7
# -4.0000000000000038e-109 0.8
# -4.000000000000004e-110 0.9
# -4.000000000000004e-111 1.0
# -4.000000000000004e-112 1.1
# -4.000000000000004e-113 1.2
# -4.000000000000004e-114 1.3
# -4.000000000000004e-115 1.4
# -4.000000000000004e-116 1.5
# -4.0000000000000036e-117 1.6
# -4.0000000000000035e-118 1.7
# -4.0000000000000034e-119 1.8
# -4.0000000000000034e-120 1.9
# -4.000000000000003e-121 2.0
# -4.0000000000000035e-122 2.1
# -4.0000000000000036e-123 2.2
# -4.000000000000004e-124 2.3
# -4.0000000000000037e-125 2.4
# -4.000000000000004e-126 2.5
# -4.000000000000003e-127 2.6
# -4.0000000000000033e-128 2.7
# -4.0000000000000035e-129 2.8
# -3.000000000000008e-101 0.0
# -3.000000000000008e-102 0.1
# -3.000000000000008e-103 0.2
# ...
